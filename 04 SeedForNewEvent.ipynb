# %%
import os
import pandas as pd

# %% [markdown]
# ## Load previous ranked data

# %%
file_path = 'ranked/ranked.csv'

# Read the CSV file into a DataFrame
ranked_dataframe = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(ranked_dataframe.head())
# Out:
#              Namn  Rank FMCK Skövde  Rank Tidaholms MK  Rank Töreboda MK  \
# 0  Hugo Andersson               6.0                3.0               1.0
# 1     Per Korsell               NaN                NaN               NaN
# 2    Olof Backman               NaN                NaN               4.0
# 3   William Almén               3.0                7.0               2.0
# 4     Niklas Mörk              11.0                5.0               3.0
#
#    Rank Carlsborgs MK  Rank Falköpings MK  Rank Tibro MK         Klass  \
# 0                 1.0                 2.0            NaN     Ungdom E1
# 1                 NaN                 4.0            2.0  Motion 40-49
# 2                 NaN                 NaN            NaN     Ungdom E1
# 3                 4.0                11.0            1.0     Ungdom E1
# 4                 3.0                 3.0            4.0    Motion -39
#
#           Klubb   AvgRank
# 0      Tibro MK  2.600000
# 1     Götene MK  3.000000
# 2  Karlskoga EK  4.000000
# 3   SMK Värnamo  4.666667
# 4       Laxå MK  4.833333

# %% [markdown]
# ## load participants for an upcoming event.

# %%
file_path = 'unseeded/unseeded.csv'

# Read the CSV file into a DataFrame with the second row as column names
unseeded_dataframe = pd.read_csv(file_path, encoding='cp1252', header=0)

# Display the first few rows of the DataFrame
print(unseeded_dataframe.head(-10))
# Out:
#     Tidaholms MK  2024     #                         Namn               Klubb  \
# 0            NaN   NaN   900                Hans Torsborn      Ulricehamns MK
# 1            NaN   NaN   902               Peter Berggren       BMK Uddevalla
# 2            NaN   NaN   903              Björn Bäckström              MK Ran
# 3            NaN   NaN   905                Per Norlander         Kullings MS
# 4            NaN   NaN   906  Anders Billestedt Andersson     Stenungsunds MS
# 5            NaN   NaN   908          Johan Alexandersson           Götene MK
# 6            NaN   NaN   912          Lars-Olof Lindström          FMCK Borås
# 7            NaN   NaN   913             Daniel Blomqvist         FMCK Skövde
# 8            NaN   NaN   914             Niklas Utterberg     Norrahammars MK
# 9            NaN   NaN   915               Martin Jonsson         Töreboda MK
# 10           NaN   NaN   917             Fredrik Hassesjö         Kullings MS
# 11           NaN   NaN   920         Christoffer Johnsson        Hisingens MK
# 12           NaN   NaN   921              Mattias Roslund  Försvarsmaktens EK
# 13           NaN   NaN   922                Mikael Sahlin      Lidköpings MCK
# 14           NaN   NaN   924           Sebastian Carlsson        SMK Vadstena
# 15           NaN   NaN   927               Mikael Dalåsen     SMK Trollhättan
# 16           NaN   NaN   929             Daniel Lundqvist         Töreboda MK
# 17           NaN   NaN   931                 Andreas Leth       Älvbygdens MK
# 18           NaN   NaN   934               Johan Karlsson       Älvbygdens MK
# 19           NaN   NaN   937                 David Rudhem      Lidköpings MCK
# 20           NaN   NaN   945             Markus Björklund              Hjo MK
# 21           NaN   NaN   962              Jonas Bergqvist            Skene MS
# 22           NaN   NaN   966              Jimmy Andersson     Stenungsunds MS
# 23           NaN   NaN   971             Jonas Gustafsson           Götene MK
# 24           NaN   NaN   973         Ola Daniel Strandvad              Viking
# 25           NaN   NaN   974               Jonas Svensson       Hallsbergs MK
# 26           NaN   NaN   978                 Kim Dubriang         Limhamns MK
# 27           NaN   NaN   985              Joakim Ericsson         Töreboda MK
# 28           NaN   NaN   990               Johan Kjellson         FMCK Skövde
# 29           NaN   NaN   998             Andreas Sandberg          FMCK Borås
# 30           NaN   NaN   999              Johan Törnqvist         FMCK Skövde
# 31           NaN   NaN  1006           Anton Bernhardsson        Kortedala MK
# 32           NaN   NaN   911                 Robert Ahlin       Falköpings MK
# 33           NaN   NaN   501           Robert Hjalmarsson          MK Pionjär
# 34           NaN   NaN   502                   Marwin Wik            Skene MS
# 35           NaN   NaN   503          Christopher Skansen            Kinds MK
# 36           NaN   NaN   504              Christer Strand            Tibro MK
# 37           NaN   NaN   505                  Viktor Blom            Skene MS
# 38           NaN   NaN   506              Robert Stafsing         Varbergs MK
# 39           NaN   NaN   508                Maria Thomsen          FMCK Borås
# 40           NaN   NaN   509               Hugo Lindström          FMCK Borås
# 41           NaN   NaN   510             Simon Gustafsson       Älvbygdens MK
# 42           NaN   NaN   511                  Dennis Ring          FMCK Borås
# 43           NaN   NaN   513                 Niklas Kedén              Hjo MK
# 44           NaN   NaN   517            Patric Gustafsson        Huskvarna MK
# 45           NaN   NaN   530                Patrik Olsson     Lilla Edets MCK
# 46           NaN   NaN   547              Felix Johansson            Kinds MK
# 47           NaN   NaN   550              Eric Gustafsson        SMK Vingåker
# 48           NaN   NaN   556             Tommy Gustafsson        Huskvarna MK
# 49           NaN   NaN   585          Ludvig Bernhardsson        Kortedala MK
# 50           NaN   NaN   590               Tobias Hagelin          FMCK Borås
# 51           NaN   NaN   594                 Anton Torgin          Donkelo RK
# 52           NaN   NaN   622        Oscar Kalliomäki Berg     Lilla Edets MCK
# 53           NaN   NaN   757               Simon Karlsson     Stenungsunds MS
# 54           NaN   NaN   102                   Liam Qvist          Åbågen MCK
# 55           NaN   NaN   103              Anton Magnusson     Norrahammars MK
#
#     Unnamed: 5
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53         NaN
# 54         NaN
# 55         NaN

# %%
# Merge or lookup operation to find the AvgRank from ranked_dataframe for each row in unseeded_dataframe
seeded_df = unseeded_dataframe.merge(
    ranked_dataframe[['Namn', 'Klubb', 'AvgRank']],  # Selecting necessary columns from ranked_dataframe
    on=['Namn', 'Klubb'],  # Merging on 'Namn' and 'Klubb' columns
    how='left'  # Perform a left join to keep all rows from unseeded_dataframe
)

# Rename the 'AvgRank' column to 'Seeding'
seeded_df.rename(columns={'AvgRank': 'Seeding'}, inplace=True)

# Find the maximum AvgRank from ranked_dataframe
max_avg_rank = ranked_dataframe['AvgRank'].max()

# Fill missing Seeding values with the maximum AvgRank plus 1
seeded_df['Seeding'].fillna(max_avg_rank + 1, inplace=True)


# Sort by Seeding column
seeded_df = seeded_df.sort_values(by='Seeding')

seeded_df.head(-10)
# Out:
#     Tidaholms MK  2024     #                         Namn               Klubb  \
# 61           NaN   NaN   141  William Brehag Von Haugwitz       Carlsborgs MK
# 21           NaN   NaN   962              Jonas Bergqvist            Skene MS
# 46           NaN   NaN   547              Felix Johansson            Kinds MK
# 14           NaN   NaN   924           Sebastian Carlsson        SMK Vadstena
# 0            NaN   NaN   900                Hans Torsborn      Ulricehamns MK
# 27           NaN   NaN   985              Joakim Ericsson         Töreboda MK
# 45           NaN   NaN   530                Patrik Olsson     Lilla Edets MCK
# 31           NaN   NaN  1006           Anton Bernhardsson        Kortedala MK
# 54           NaN   NaN   102                   Liam Qvist          Åbågen MCK
# 18           NaN   NaN   934               Johan Karlsson       Älvbygdens MK
# 6            NaN   NaN   912          Lars-Olof Lindström          FMCK Borås
# 2            NaN   NaN   903              Björn Bäckström              MK Ran
# 16           NaN   NaN   929             Daniel Lundqvist         Töreboda MK
# 42           NaN   NaN   511                  Dennis Ring          FMCK Borås
# 36           NaN   NaN   504              Christer Strand            Tibro MK
# 44           NaN   NaN   517            Patric Gustafsson        Huskvarna MK
# 40           NaN   NaN   509               Hugo Lindström          FMCK Borås
# 25           NaN   NaN   974               Jonas Svensson       Hallsbergs MK
# 47           NaN   NaN   550              Eric Gustafsson        SMK Vingåker
# 43           NaN   NaN   513                 Niklas Kedén              Hjo MK
# 23           NaN   NaN   971             Jonas Gustafsson           Götene MK
# 48           NaN   NaN   556             Tommy Gustafsson        Huskvarna MK
# 11           NaN   NaN   920         Christoffer Johnsson        Hisingens MK
# 8            NaN   NaN   914             Niklas Utterberg     Norrahammars MK
# 28           NaN   NaN   990               Johan Kjellson         FMCK Skövde
# 4            NaN   NaN   906  Anders Billestedt Andersson     Stenungsunds MS
# 7            NaN   NaN   913             Daniel Blomqvist         FMCK Skövde
# 32           NaN   NaN   911                 Robert Ahlin       Falköpings MK
# 56           NaN   NaN   104                 Lisa Nyqvist     Stenungsunds MS
# 41           NaN   NaN   510             Simon Gustafsson       Älvbygdens MK
# 9            NaN   NaN   915               Martin Jonsson         Töreboda MK
# 13           NaN   NaN   922                Mikael Sahlin      Lidköpings MCK
# 34           NaN   NaN   502                   Marwin Wik            Skene MS
# 1            NaN   NaN   902               Peter Berggren       BMK Uddevalla
# 65           NaN   NaN   199                 William Blom            Skene MS
# 39           NaN   NaN   508                Maria Thomsen          FMCK Borås
# 30           NaN   NaN   999              Johan Törnqvist         FMCK Skövde
# 51           NaN   NaN   594                 Anton Torgin          Donkelo RK
# 50           NaN   NaN   590               Tobias Hagelin          FMCK Borås
# 29           NaN   NaN   998             Andreas Sandberg          FMCK Borås
# 59           NaN   NaN   120                Albin Glansén        Tidaholms MK
# 60           NaN   NaN   121              William Larsson         FMCK Skövde
# 62           NaN   NaN   163               Erik Frisagård          Getinge MK
# 55           NaN   NaN   103              Anton Magnusson     Norrahammars MK
# 3            NaN   NaN   905                Per Norlander         Kullings MS
# 63           NaN   NaN   176                   Leo Revelj       BMK Uddevalla
# 53           NaN   NaN   757               Simon Karlsson     Stenungsunds MS
# 52           NaN   NaN   622        Oscar Kalliomäki Berg     Lilla Edets MCK
# 58           NaN   NaN   113           Benjamin Bengtsson       Falköpings MK
# 57           NaN   NaN   106             Hampus Andersson            Tibro MK
# 24           NaN   NaN   973         Ola Daniel Strandvad              Viking
# 5            NaN   NaN   908          Johan Alexandersson           Götene MK
# 26           NaN   NaN   978                 Kim Dubriang         Limhamns MK
# 12           NaN   NaN   921              Mattias Roslund  Försvarsmaktens EK
# 15           NaN   NaN   927               Mikael Dalåsen     SMK Trollhättan
# 17           NaN   NaN   931                 Andreas Leth       Älvbygdens MK
#
#     Unnamed: 5     Seeding
# 61         NaN   15.400000
# 21         NaN   34.000000
# 46         NaN   34.500000
# 14         NaN   36.750000
# 0          NaN   44.000000
# 27         NaN   45.166667
# 45         NaN   50.000000
# 31         NaN   50.500000
# 54         NaN   52.000000
# 18         NaN   57.750000
# 6          NaN   60.000000
# 2          NaN   61.666667
# 16         NaN   62.200000
# 42         NaN   79.000000
# 36         NaN   84.500000
# 44         NaN   84.500000
# 40         NaN   87.750000
# 25         NaN   88.666667
# 47         NaN   92.200000
# 43         NaN   96.000000
# 23         NaN   97.600000
# 48         NaN   99.166667
# 11         NaN  104.666667
# 8          NaN  107.000000
# 28         NaN  107.833333
# 4          NaN  112.800000
# 7          NaN  114.800000
# 32         NaN  115.250000
# 56         NaN  120.000000
# 41         NaN  121.500000
# 9          NaN  124.333333
# 13         NaN  125.000000
# 34         NaN  139.800000
# 1          NaN  144.666667
# 65         NaN  144.800000
# 39         NaN  149.500000
# 30         NaN  150.333333
# 51         NaN  153.000000
# 50         NaN  154.000000
# 29         NaN  158.500000
# 59         NaN  197.000000
# 60         NaN  197.000000
# 62         NaN  197.000000
# 55         NaN  197.000000
# 3          NaN  197.000000
# 63         NaN  197.000000
# 53         NaN  197.000000
# 52         NaN  197.000000
# 58         NaN  197.000000
# 57         NaN  197.000000
# 24         NaN  197.000000
# 5          NaN  197.000000
# 26         NaN  197.000000
# 12         NaN  197.000000
# 15         NaN  197.000000
# 17         NaN  197.000000

# %%
seeded_df['Seeding'] = seeded_df.reset_index(drop=True).index + 1

seeded_df.head(-10)
# Out:
#     Tidaholms MK  2024     #                         Namn               Klubb  \
# 61           NaN   NaN   141  William Brehag Von Haugwitz       Carlsborgs MK
# 21           NaN   NaN   962              Jonas Bergqvist            Skene MS
# 46           NaN   NaN   547              Felix Johansson            Kinds MK
# 14           NaN   NaN   924           Sebastian Carlsson        SMK Vadstena
# 0            NaN   NaN   900                Hans Torsborn      Ulricehamns MK
# 27           NaN   NaN   985              Joakim Ericsson         Töreboda MK
# 45           NaN   NaN   530                Patrik Olsson     Lilla Edets MCK
# 31           NaN   NaN  1006           Anton Bernhardsson        Kortedala MK
# 54           NaN   NaN   102                   Liam Qvist          Åbågen MCK
# 18           NaN   NaN   934               Johan Karlsson       Älvbygdens MK
# 6            NaN   NaN   912          Lars-Olof Lindström          FMCK Borås
# 2            NaN   NaN   903              Björn Bäckström              MK Ran
# 16           NaN   NaN   929             Daniel Lundqvist         Töreboda MK
# 42           NaN   NaN   511                  Dennis Ring          FMCK Borås
# 36           NaN   NaN   504              Christer Strand            Tibro MK
# 44           NaN   NaN   517            Patric Gustafsson        Huskvarna MK
# 40           NaN   NaN   509               Hugo Lindström          FMCK Borås
# 25           NaN   NaN   974               Jonas Svensson       Hallsbergs MK
# 47           NaN   NaN   550              Eric Gustafsson        SMK Vingåker
# 43           NaN   NaN   513                 Niklas Kedén              Hjo MK
# 23           NaN   NaN   971             Jonas Gustafsson           Götene MK
# 48           NaN   NaN   556             Tommy Gustafsson        Huskvarna MK
# 11           NaN   NaN   920         Christoffer Johnsson        Hisingens MK
# 8            NaN   NaN   914             Niklas Utterberg     Norrahammars MK
# 28           NaN   NaN   990               Johan Kjellson         FMCK Skövde
# 4            NaN   NaN   906  Anders Billestedt Andersson     Stenungsunds MS
# 7            NaN   NaN   913             Daniel Blomqvist         FMCK Skövde
# 32           NaN   NaN   911                 Robert Ahlin       Falköpings MK
# 56           NaN   NaN   104                 Lisa Nyqvist     Stenungsunds MS
# 41           NaN   NaN   510             Simon Gustafsson       Älvbygdens MK
# 9            NaN   NaN   915               Martin Jonsson         Töreboda MK
# 13           NaN   NaN   922                Mikael Sahlin      Lidköpings MCK
# 34           NaN   NaN   502                   Marwin Wik            Skene MS
# 1            NaN   NaN   902               Peter Berggren       BMK Uddevalla
# 65           NaN   NaN   199                 William Blom            Skene MS
# 39           NaN   NaN   508                Maria Thomsen          FMCK Borås
# 30           NaN   NaN   999              Johan Törnqvist         FMCK Skövde
# 51           NaN   NaN   594                 Anton Torgin          Donkelo RK
# 50           NaN   NaN   590               Tobias Hagelin          FMCK Borås
# 29           NaN   NaN   998             Andreas Sandberg          FMCK Borås
# 59           NaN   NaN   120                Albin Glansén        Tidaholms MK
# 60           NaN   NaN   121              William Larsson         FMCK Skövde
# 62           NaN   NaN   163               Erik Frisagård          Getinge MK
# 55           NaN   NaN   103              Anton Magnusson     Norrahammars MK
# 3            NaN   NaN   905                Per Norlander         Kullings MS
# 63           NaN   NaN   176                   Leo Revelj       BMK Uddevalla
# 53           NaN   NaN   757               Simon Karlsson     Stenungsunds MS
# 52           NaN   NaN   622        Oscar Kalliomäki Berg     Lilla Edets MCK
# 58           NaN   NaN   113           Benjamin Bengtsson       Falköpings MK
# 57           NaN   NaN   106             Hampus Andersson            Tibro MK
# 24           NaN   NaN   973         Ola Daniel Strandvad              Viking
# 5            NaN   NaN   908          Johan Alexandersson           Götene MK
# 26           NaN   NaN   978                 Kim Dubriang         Limhamns MK
# 12           NaN   NaN   921              Mattias Roslund  Försvarsmaktens EK
# 15           NaN   NaN   927               Mikael Dalåsen     SMK Trollhättan
# 17           NaN   NaN   931                 Andreas Leth       Älvbygdens MK
#
#     Unnamed: 5  Seeding
# 61         NaN        1
# 21         NaN        2
# 46         NaN        3
# 14         NaN        4
# 0          NaN        5
# 27         NaN        6
# 45         NaN        7
# 31         NaN        8
# 54         NaN        9
# 18         NaN       10
# 6          NaN       11
# 2          NaN       12
# 16         NaN       13
# 42         NaN       14
# 36         NaN       15
# 44         NaN       16
# 40         NaN       17
# 25         NaN       18
# 47         NaN       19
# 43         NaN       20
# 23         NaN       21
# 48         NaN       22
# 11         NaN       23
# 8          NaN       24
# 28         NaN       25
# 4          NaN       26
# 7          NaN       27
# 32         NaN       28
# 56         NaN       29
# 41         NaN       30
# 9          NaN       31
# 13         NaN       32
# 34         NaN       33
# 1          NaN       34
# 65         NaN       35
# 39         NaN       36
# 30         NaN       37
# 51         NaN       38
# 50         NaN       39
# 29         NaN       40
# 59         NaN       41
# 60         NaN       42
# 62         NaN       43
# 55         NaN       44
# 3          NaN       45
# 63         NaN       46
# 53         NaN       47
# 52         NaN       48
# 58         NaN       49
# 57         NaN       50
# 24         NaN       51
# 5          NaN       52
# 26         NaN       53
# 12         NaN       54
# 15         NaN       55
# 17         NaN       56

# %%
import datetime

folder_name = 'seeded'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
# Get the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H%M")

# Define the filename with the current timestamp
file_name = f"seeded/{current_time}.csv"

# Save the DataFrame to a CSV file
try:
    seeded_df.to_csv(file_name, index=False, encoding='cp1252')  # Windows-1252 encoding
    print(f"Ranked data saved successfully to '{file_name}'")
except Exception as e:
    print(f"Error saving ranked data: {e}")
# Out:
# Ranked data saved successfully to 'seeded/2023-12-18_0734.csv'
