# %%
import os
import re
import pandas as pd
import numpy as np

# %%
# Folder containing CSV files
folder_path = '../src/lap_times_fixed/'

# List all files in the folder ending with '.csv'
file_paths = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith('.csv')]

# Initialize a dictionary to store dataframes
dataframes = {}

# Loop through each file and read its data into a pandas DataFrame
for file_path in file_paths:
    # Extract file name without extension
    file_name = os.path.splitext(os.path.basename(file_path))[0]
    
    # Read CSV into a dataframe and store it in the dictionary
    dataframes[file_name] = pd.read_csv(file_path)

# %% [markdown]
# ## Check dataframe content

# %%
dataframes['Dataframe_1'].head()
# Out:
#          Plats    År  Plac         Klass     #              Namn  \
# 0  FMCK Skövde  2023   1.0  Motion 40-49  1111     Magnus Edberg
# 1  FMCK Skövde  2023   2.0    Motion -39   518    Alexander Fält
# 2  FMCK Skövde  2023   3.0    Motion -39   577        Måns Dalén
# 3  FMCK Skövde  2023   4.0     Ungdom E1   175     William Almén
# 4  FMCK Skövde  2023   5.0  Motion 40-49   944  Niklas Strömberg
#
#                 Klubb  Varv      Tid   Varv 1   Varv 2   Varv 3   Varv 4  \
# 0        Huskvarna MK     4  53:05.5  14:08.2  14:17.5  11:47.5  12:52.1
# 1  Försvarsmaktens EK     4  53:45.2  14:38.8  14:31.4  12:13.6  12:21.2
# 2         FMCK Skövde     4  53:51.5  14:20.4  14:53.3  12:03.4  12:34.3
# 3         SMK Värnamo     4  54:06.2  14:26.6  14:50.0  12:07.0  12:42.5
# 4           Götene MK     4  54:13.8  14:40.2  15:07.9  11:56.7  12:28.9
#
#   Varv 5 Varv 6
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN

# %% [markdown]
# ## Convert lap times to time seconds format.

# %%
# Function to convert lap time strings to seconds
def convert_to_seconds(lap_time):
    if pd.notnull(lap_time) and isinstance(lap_time, str) and ':' in lap_time:
        minutes, rest = lap_time.split(':')
        seconds_tenths = rest.split('.')
        if len(seconds_tenths) == 2:
            seconds, tenths = map(int, seconds_tenths)
            total_seconds = int(minutes) * 60 + seconds + tenths / 10
            return total_seconds
    return pd.NaT if pd.notnull(lap_time) else pd.NaT

# Apply the conversion function to lap time columns
for df_name in dataframes:
    varv_columns = [col for col in dataframes[df_name].columns if col.startswith('Varv ')]
    for col in varv_columns:
        dataframes[df_name][col] = dataframes[df_name][col].apply(convert_to_seconds)
        dataframes[df_name][col] = dataframes[df_name][col].replace({'KÖR': pd.NaT, 'BRUTIT': pd.NaT})

# %%
dataframes['Dataframe_1'].head()
# Out:
#          Plats    År  Plac         Klass     #              Namn  \
# 0  FMCK Skövde  2023   1.0  Motion 40-49  1111     Magnus Edberg
# 1  FMCK Skövde  2023   2.0    Motion -39   518    Alexander Fält
# 2  FMCK Skövde  2023   3.0    Motion -39   577        Måns Dalén
# 3  FMCK Skövde  2023   4.0     Ungdom E1   175     William Almén
# 4  FMCK Skövde  2023   5.0  Motion 40-49   944  Niklas Strömberg
#
#                 Klubb  Varv      Tid Varv 1 Varv 2 Varv 3 Varv 4 Varv 5 Varv 6
# 0        Huskvarna MK     4  53:05.5  848.2  857.5  707.5  772.1    NaT    NaT
# 1  Försvarsmaktens EK     4  53:45.2  878.8  871.4  733.6  741.2    NaT    NaT
# 2         FMCK Skövde     4  53:51.5  860.4  893.3  723.4  754.3    NaT    NaT
# 3         SMK Värnamo     4  54:06.2  866.6  890.0  727.0  762.5    NaT    NaT
# 4           Götene MK     4  54:13.8  880.2  907.9  716.7  748.9    NaT    NaT

# %% [markdown]
# ## Find fastest lap time in odd Varv columns

# %%
# Function to find the fastest lap time from odd-numbered "Varv " columns
def fastest_odd_lap(row):
    odd_varv_cols = [col for col in row.index if col.startswith('Varv ') and int(col.split()[-1]) % 2 != 0]
    odd_lap_times = [row[col] for col in odd_varv_cols if not pd.isnull(row[col])]
    if odd_lap_times:
        return min(odd_lap_times)
    return np.nan  # or pd.NaT if preferred

# Iterate through all Dataframes and add the "FastestOddLap" column
for df_name, df in dataframes.items():
    df['FastestOddLap'] = df.apply(fastest_odd_lap, axis=1)

# %%
dataframes['Dataframe_1'].head()
# Out:
#          Plats    År  Plac         Klass     #              Namn  \
# 0  FMCK Skövde  2023   1.0  Motion 40-49  1111     Magnus Edberg
# 1  FMCK Skövde  2023   2.0    Motion -39   518    Alexander Fält
# 2  FMCK Skövde  2023   3.0    Motion -39   577        Måns Dalén
# 3  FMCK Skövde  2023   4.0     Ungdom E1   175     William Almén
# 4  FMCK Skövde  2023   5.0  Motion 40-49   944  Niklas Strömberg
#
#                 Klubb  Varv      Tid Varv 1 Varv 2 Varv 3 Varv 4 Varv 5  \
# 0        Huskvarna MK     4  53:05.5  848.2  857.5  707.5  772.1    NaT
# 1  Försvarsmaktens EK     4  53:45.2  878.8  871.4  733.6  741.2    NaT
# 2         FMCK Skövde     4  53:51.5  860.4  893.3  723.4  754.3    NaT
# 3         SMK Värnamo     4  54:06.2  866.6  890.0  727.0  762.5    NaT
# 4           Götene MK     4  54:13.8  880.2  907.9  716.7  748.9    NaT
#
#   Varv 6  FastestOddLap
# 0    NaT          707.5
# 1    NaT          733.6
# 2    NaT          723.4
# 3    NaT          727.0
# 4    NaT          716.7

# %% [markdown]
# ## Find fastest lap time in even Varv columns

# %%
# Function to find the fastest lap time from even-numbered "Varv " columns
def fastest_even_lap(row):
    even_varv_cols = [col for col in row.index if col.startswith('Varv ') and int(col.split()[-1]) % 2 == 0]
    even_lap_times = [row[col] for col in even_varv_cols if not pd.isnull(row[col])]
    if even_lap_times:
        return min(even_lap_times)
    return np.nan  # or pd.NaT if preferred

# Iterate through all Dataframes and add the "FastestEvenLap" column
for df_name, df in dataframes.items():
    df['FastestEvenLap'] = df.apply(fastest_even_lap, axis=1)

# %%
dataframes['Dataframe_1'].head(-10)
# Out:
#            Plats    År  Plac         Klass     #  \
# 0    FMCK Skövde  2023   1.0  Motion 40-49  1111
# 1    FMCK Skövde  2023   2.0    Motion -39   518
# 2    FMCK Skövde  2023   3.0    Motion -39   577
# 3    FMCK Skövde  2023   4.0     Ungdom E1   175
# 4    FMCK Skövde  2023   5.0  Motion 40-49   944
# ..           ...   ...   ...           ...   ...
# 356  FMCK Skövde  2023  75.0         Bredd   212
# 357  FMCK Skövde  2023  76.0        Junior   134
# 358  FMCK Skövde  2023  77.0         Bredd   336
# 359  FMCK Skövde  2023  78.0         Bredd   269
# 360  FMCK Skövde  2023  79.0           Dam   407
#
#                                   Namn               Klubb  Varv      Tid  \
# 0                        Magnus Edberg        Huskvarna MK     4  53:05.5
# 1                       Alexander Fält  Försvarsmaktens EK     4  53:45.2
# 2                           Måns Dalén         FMCK Skövde     4  53:51.5
# 3                        William Almén         SMK Värnamo     4  54:06.2
# 4                     Niklas Strömberg           Götene MK     4  54:13.8
# ..                                 ...                 ...   ...      ...
# 356                   Melker Djurstedt        Djursdala SK     5  38:00.3
# 357                       Max Nordmark         Varbergs MK     5  41:12.0
# 358                  Andreas Johansson       Carlsborgs MK     4  55:53.0
# 359        Albin Bäckström Herbertsson          Säffle MCK     4  04:29.8
# 360  Matilda Alexandersson Fridolfsson           Götene MK     4  24:21.2
#
#      Varv 1  Varv 2  Varv 3  Varv 4  Varv 5 Varv 6  FastestOddLap  \
# 0     848.2   857.5   707.5   772.1     NaN    NaN          707.5
# 1     878.8   871.4   733.6   741.2     NaN    NaN          733.6
# 2     860.4   893.3   723.4   754.3     NaN    NaN          723.4
# 3     866.6   890.0   727.0   762.5     NaN    NaN          727.0
# 4     880.2   907.9   716.7   748.9     NaN    NaN          716.7
# ..      ...     ...     ...     ...     ...    ...            ...
# 356  1085.6  1127.6  1168.8  1266.1  1232.0    NaN         1085.6
# 357  1083.4  1216.0  1180.8  1465.6  1126.0    NaN         1083.4
# 358   773.4   825.7   803.5   950.3     NaT    NaN          773.4
# 359   912.4   974.6   922.8  1059.8     NaT    NaN          912.4
# 360  1172.6  1181.8  1225.9  1480.7     NaT    NaN         1172.6
#
#      FastestEvenLap
# 0             772.1
# 1             741.2
# 2             754.3
# 3             762.5
# 4             748.9
# ..              ...
# 356          1127.6
# 357          1216.0
# 358           825.7
# 359           974.6
# 360          1181.8
#
# [361 rows x 17 columns]

# %% [markdown]
# ## Drop rows that don't have enough data.

# %%
# Delete rows with missing values in Varv 2 and Varv 3 columns
for df_name, df in dataframes.items():
    columns_to_check = ['Varv 2', 'Varv 3']  # Columns Varv 2 and Varv 3 only
    df.dropna(subset=columns_to_check, how='any', inplace=True)

# %% [markdown]
# ## Check for missing data

# %%
# Find and print rows with missing values in FastestOddLap or FastestEvenLap columns
for df_name, df in dataframes.items():
    missing_values = df[df[['FastestOddLap', 'FastestEvenLap']].isnull().any(axis=1)]
    if not missing_values.empty:
        print(f"DataFrame {df_name}: Rows with missing values in FastestOddLap or FastestEvenLap:")
        print(missing_values)
    else:
        print(f"DataFrame {df_name}: No rows with missing values in FastestOddLap or FastestEvenLap.")
# Out:
# DataFrame Dataframe_1: No rows with missing values in FastestOddLap or FastestEvenLap.
# DataFrame Dataframe_2: No rows with missing values in FastestOddLap or FastestEvenLap.
# DataFrame Dataframe_3: No rows with missing values in FastestOddLap or FastestEvenLap.
# DataFrame Dataframe_4: No rows with missing values in FastestOddLap or FastestEvenLap.
# DataFrame Dataframe_5: No rows with missing values in FastestOddLap or FastestEvenLap.
# DataFrame Dataframe_6: No rows with missing values in FastestOddLap or FastestEvenLap.

# %% [markdown]
# ## Calculate average of fastest odd and even laps.

# %%
# Calculate average of FastestOddLap and FastestEvenLap and add to AvgFastestLap column
for df_name, df in dataframes.items():
    df['AvgFastestLap'] = df[['FastestOddLap', 'FastestEvenLap']].mean(axis=1)

# %%
dataframes['Dataframe_1'].head(-10)
# Out:
#            Plats    År  Plac         Klass     #                 Namn  \
# 0    FMCK Skövde  2023   1.0  Motion 40-49  1111        Magnus Edberg
# 1    FMCK Skövde  2023   2.0    Motion -39   518       Alexander Fält
# 2    FMCK Skövde  2023   3.0    Motion -39   577           Måns Dalén
# 3    FMCK Skövde  2023   4.0     Ungdom E1   175        William Almén
# 4    FMCK Skövde  2023   5.0  Motion 40-49   944     Niklas Strömberg
# ..           ...   ...   ...           ...   ...                  ...
# 352  FMCK Skövde  2023  71.0         Bredd   234        Patrik Kerttu
# 353  FMCK Skövde  2023  72.0        Junior   172  Alexander Andersson
# 354  FMCK Skövde  2023  73.0           Dam   415     emelie johansson
# 355  FMCK Skövde  2023  74.0         Bredd   311        Johan Wolgers
# 356  FMCK Skövde  2023  75.0         Bredd   212     Melker Djurstedt
#
#                   Klubb  Varv      Tid  Varv 1  Varv 2  Varv 3  Varv 4  \
# 0          Huskvarna MK     4  53:05.5   848.2   857.5   707.5   772.1
# 1    Försvarsmaktens EK     4  53:45.2   878.8   871.4   733.6   741.2
# 2           FMCK Skövde     4  53:51.5   860.4   893.3   723.4   754.3
# 3           SMK Värnamo     4  54:06.2   866.6   890.0   727.0   762.5
# 4             Götene MK     4  54:13.8   880.2   907.9   716.7   748.9
# ..                  ...   ...      ...     ...     ...     ...     ...
# 352        Kortedala MK     5  30:23.4   931.7  1021.8  1158.9  1168.5
# 353          Tranemo MK     5  35:10.1   915.5  1196.3  1251.3  1116.3
# 354           Götene MK     5  35:10.7  1017.2  1103.7  1107.1  1302.5
# 355          FMCK Borås     5  37:50.4  1039.6  1154.0  1161.9  1373.3
# 356        Djursdala SK     5  38:00.3  1085.6  1127.6  1168.8  1266.1
#
#      Varv 5 Varv 6  FastestOddLap  FastestEvenLap  AvgFastestLap
# 0       NaN    NaN          707.5           772.1         739.80
# 1       NaN    NaN          733.6           741.2         737.40
# 2       NaN    NaN          723.4           754.3         738.85
# 3       NaN    NaN          727.0           762.5         744.75
# 4       NaN    NaN          716.7           748.9         732.80
# ..      ...    ...            ...             ...            ...
# 352  1142.2    NaN          931.7          1021.8         976.75
# 353  1230.5    NaN          915.5          1116.3        1015.90
# 354  1180.1    NaN         1017.2          1103.7        1060.45
# 355  1141.4    NaN         1039.6          1154.0        1096.80
# 356  1232.0    NaN         1085.6          1127.6        1106.60
#
# [338 rows x 18 columns]

# %% [markdown]
# ## Sort data on AvgFastestLap columns

# %%
# Sort each DataFrame by AvgFastestLap column
for df_name, df in dataframes.items():
    dataframes[df_name] = df.sort_values(by='AvgFastestLap')

# %%
dataframes['Dataframe_1'].head(-10)
# Out:
#            Plats    År   Plac         Klass     #              Namn  \
# 282  FMCK Skövde  2023    1.0        Senior     1     Albin Elowson
# 283  FMCK Skövde  2023    2.0        Senior     6  Oskar Ljungström
# 284  FMCK Skövde  2023    3.0        Junior   182    Arvid Karlsson
# 285  FMCK Skövde  2023    4.0        Senior    20    Robert Friberg
# 288  FMCK Skövde  2023    7.0        Senior     5   Nisse Bengtsson
# ..           ...   ...    ...           ...   ...               ...
# 256  FMCK Skövde  2023  113.0  Motion 50-59  1473      Håkan Jägmar
# 134  FMCK Skövde  2023  135.0     Ungdom E1   124      Sam Aronsson
# 255  FMCK Skövde  2023  112.0     Ungdom E0    11   Alicia Isaksson
# 366  FMCK Skövde  2023   85.0           Dam   429    Tilda Mehtonen
# 263  FMCK Skövde  2023  120.0  Motion 50-59  1368   Anders Engström
#
#                Klubb  Varv      Tid  Varv 1  Varv 2  Varv 3  Varv 4 Varv 5  \
# 282      FMCK Skövde     6  02:44.8   583.3   628.4   594.0   639.4  634.9
# 283    Falköpings MK     6  05:06.5   601.1   648.1   624.3   666.4  661.3
# 284      FMCK Skövde     6  07:22.3   646.2   672.8   645.2   685.1  683.1
# 285      FMCK Skövde     6  07:31.5   643.4   679.3   647.3   697.5  678.4
# 288     Tidaholms MK     6  09:12.2   624.9   698.0   664.1   710.6  689.7
# ..               ...   ...      ...     ...     ...     ...     ...    ...
# 256  Norrahammars MK     4  26:09.5  1308.6  1482.1  1165.3  1213.3    NaN
# 134      Töreboda MK     4  29:33.2  1765.3  1221.6  1226.8  1159.4    NaN
# 255    Falköpings MK     4  22:50.8  1323.1  1207.2  1203.9  1236.6    NaN
# 366      FMCK Skövde     3  01:52.7  1030.3  1442.9  1239.5     NaT    NaN
# 263  Stenungsunds MS     3  02:54.8  1248.3  1236.6  1289.8     NaT    NaN
#
#     Varv 6  FastestOddLap  FastestEvenLap  AvgFastestLap
# 282  684.6          583.3           628.4         605.85
# 283  705.1          601.1           648.1         624.60
# 284  709.7          645.2           672.8         659.00
# 285  705.3          643.4           679.3         661.35
# 288  764.6          624.9           698.0         661.45
# ..     ...            ...             ...            ...
# 256    NaN         1165.3          1213.3        1189.30
# 134    NaN         1226.8          1159.4        1193.10
# 255    NaN         1203.9          1207.2        1205.55
# 366    NaN         1030.3          1442.9        1236.60
# 263    NaN         1248.3          1236.6        1242.45
#
# [338 rows x 18 columns]
