# %% [markdown]
# ## Making plots
#
# This notebook is to use the ranked riders data to make plots to visualize the selected rider's ranking.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_path = 'ranked/ranked.csv'

# Read the CSV file into a DataFrame
ranked_dataframe = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(ranked_dataframe.head())
# Out:
#                        Namn         Klubb     #         Klass  \
# 0             Albin Elowson   FMCK Skövde     1          Elit
# 1  Simon Hopander Ankarhake  Nyköpings MS   304  Motion 16-29
# 2            Sören Fransson      Kinds MK  1236  Motion 50-59
# 3            Niklas Persson  Karlskoga EK    28        Senior
# 4            Rikard Hansson      Tibro MK    73        Senior
#
#    Rank FMK Skövde  Rank Tidaholms MK  Rank Töreboda MK  Rank Tibro MK  \
# 0            133.0                NaN               1.0            NaN
# 1            189.0                NaN               NaN            NaN
# 2              NaN                1.0               NaN            NaN
# 3              NaN                NaN               2.0            NaN
# 4              NaN                NaN               3.0            NaN
#
#    Rank Carlsborgs MK  Rank Falköpings MK  AvgRank
# 0                 NaN                 NaN      1.0
# 1                 NaN                 1.0      1.0
# 2               161.0                 NaN      1.0
# 3                 NaN                 NaN      2.0
# 4                 2.0                 NaN      2.0

# %%
# Sorting the DataFrame by AvgRank in descending order
sorted_df = ranked_dataframe.sort_values('AvgRank', ascending=False)

# Plotting AvgRank against Klass
plt.figure(figsize=(12, 8))
plt.bar(sorted_df['Klass'], sorted_df['AvgRank'])
plt.xlabel('Klass')
plt.ylabel('Average Rank')
plt.title('Average Rank by Class (Sorted)')
plt.xticks(rotation=90)  # Rotating x-axis labels for better readability
plt.tight_layout()

# Show plot
plt.show()

# %%
def display_row_by_name(name):
    row = ranked_dataframe[ranked_dataframe['Namn'] == name]
    if not row.empty:
        print(row)
    else:
        print(f"No data found for '{name}'.")

# Example: Displaying row for a specific name
display_row_by_name('Robert Ahlin')
# Out:
#              Namn  Rank FMK Skövde  Rank Tidaholms MK  Rank Töreboda MK  \
# 355  Robert Ahlin            123.0                NaN             304.0
#
#      Rank Carlsborgs MK  Rank Falköpings MK  Rank Tibro MK         Klass  \
# 355                 NaN                 NaN          220.0  Motion 40-49
#
#              Klubb  AvgRank
# 355  Falköpings MK    171.5

# %% [markdown]
# Show line chart for selected riders.

# %%
# Function to plot rankings for specific riders
def plot_rankings(dataframe, rider_names):
    plt.figure(figsize=(10, 6))

    for rider_name in rider_names:
        # Filter data for the rider
        rider_data = dataframe[dataframe['Namn'] == rider_name]

        # Get ranking columns
        ranking_columns = [col for col in rider_data.columns if col.startswith('Rank')]

        # Convert columns to numeric using .loc to avoid SettingWithCopyWarning
        for col in ranking_columns:
            rider_data.loc[:, col] = pd.to_numeric(rider_data[col], errors='coerce')


        # Extract rider's rankings
        rankings = rider_data[ranking_columns].fillna(np.nan).values.flatten().astype(float)

        # Plot rankings as a line chart for each rider
        plt.plot(range(1, len(rankings) + 1), rankings, marker='o', label=rider_name)

    plt.xlabel('Ranking Columns')
    plt.ylabel('Ranking')
    plt.title('Rankings for Riders')
    plt.legend()
    plt.grid(True)  # Add grid lines
    plt.show()

# Example: Plot rankings for multiple riders
riders_to_plot = ['Robert Ahlin', 'Marcus Hjelm', 'Jesper Herngren', 'Henrik Olsson', 'Christian Kurist']
plot_rankings(ranked_dataframe, riders_to_plot)

# %%
# Get unique Klubb values from ranked_dataframe
unique_klubbs = ranked_dataframe['Klubb'].unique()
print(unique_klubbs)
# Out:
# ['FMCK Skövde' 'Nyköpings MS' 'Kinds MK' 'Karlskoga EK' 'SMK Trollhättan'
#  'Tibro MK' 'Linköpings MS' 'Falköpings MK' 'Kullings MS' 'Tidaholms MK'
#  'Hallsbergs MK' 'SMK Vingåker' 'Försvarsmaktens EK' 'Götene MK'
#  'MK Orion' 'BMK Uddevalla' 'FMCK Hässleholm' 'Örebro EK' 'SMK Värnamo'
#  'Skene MS' 'Laxå MK' 'Älvbygdens MK' 'Norrahammars MK' 'Hjo MK'
#  'Tranås MS' 'Gotland Enduro Cross MS' 'Vimmerby MS' 'Huskvarna MK'
#  'Lilla Edets MCK' 'FMCK Borås' 'Battle of Vikings Sportförening'
#  'Finspångs MS' 'Djursdala SK' 'MK Pionjär' 'Carlsborgs MK'
#  'Solshesters MCK' 'MC Alingsås' 'Notodden Crossklubb' 'Borg mc klubb'
#  'Bodafors MK' 'Göta MS' 'Töreboda MK' 'Stenungsunds MS' 'Björkö EK'
#  'Kortedala MK' 'SMK Eksjö' 'Varbergs MK' 'Karlstad MX Klubb'
#  'Flittig, Flittig Enduro' 'FMCK Skövde, Tidaholms MK' 'SMK Östgöta'
#  'Älvbygdens MK, Götene MK' 'Älvbygdens MK, Falköpings MK, Götene MK'
#  'Team Westom Motorcykel' 'Fjugesta MS' 'SMK Kolmården' 'Wäxjö MS'
#  'Tranås MS, Försvarsmaktens EK' 'FMCK Strängnäs' 'Mariestads EK'
#  'Jevnaker MK' 'Tranemo MK' 'Bodafors MK, Försvarsmaktens EK' 'Åbågen MCK'
#  'Bengtsfors MCC' 'Ulricehamns MK' 'Kungsbacka MA'
#  'SMK Trollhättan, Lilla Edets MCK' 'MCK Hallandia'
#  'Falköpings MK, Götene MK' 'SMK Vadstena' 'MK Ran' 'FMCK BohusDal'
#  'Kinna MK' 'Hagfors MS' 'Norrahammars MK, Kullings MS' 'Säffle MCK'
#  'SMK Ronneby' 'Ma Lerum' 'Kristdala MS, Kristdala Motorsällskap'
#  'Team Värmland MK' 'Gotlands MF:s Motorcykelklubb' 'Alingsås MCK'
#  'Vissefjärda EK' 'Donkelo RK' 'Westerviks MSK' 'Bollnäs MK'
#  'Oskarshamns MSK' 'FMCK Eksjö' 'Kristdala Motorsällskap'
#  'SMK Östgöta, Göta MS' 'MK Team Treske' 'Botkyrka MK' 'Oslo MSK, Oslo MK'
#  'Östhammars MK' 'MK Nitro' 'Ålands MK' 'NMK Aurskog Høland' 'Borås MK'
#  'Örebro MK' 'Uppsala MK' 'SMK Uppsala' 'Haninge MK' 'Åsätra MK'
#  'Vrigstad MK' 'Hällefors MK' 'SMK Dala Falun' 'Örbyhus MCK' 'SMK Ockelbo'
#  'Mockfjärd MK' 'Hedesunda CK' 'Flittig Enduro' 'Norsjö MS' 'SMK Gävle'
#  'SMK Söderhamnsavdelning' 'Ludvika MS' 'SMK Hedemora' 'Edsvära MCK'
#  'Värmdö MK' 'Hudiksvalls MCK' 'SMC' 'Rasbo MK' 'SMK Ljungby'
#  'Beskaskinn MC, Götene MK' 'Västerås MK' 'Arlanda MC'
#  'Eds-Skottbacka MX Förening' 'Upplands Väsby MK' 'Lidköpings MCK'
#  'Mariestads EK, Skene MS' 'Kalmar Motocross & EnduroKlubb'
#  'Rättvik Boda MK' 'SMK Östgöta, Göta MS, FMCK Malmö'
#  'Flittig, Flittig, Utenlandsk klubb, Utenlandsk klubb, Flittig, Flittig Motocross og ATV'
#  'FMCK Falun' 'Hogdals Motor Klubb' 'Skutskärs MS' 'FMCK Malmö'
#  'SMK Motala MC-Klubb' 'BMK Uddevalla, Skene MS, Tidaholms MK'
#  'BMK Uddevalla, Tidaholms MK' 'Flittig MX/ATV, Flittig Enduro'
#  'Värmullsåsens Mountainbike & EK' 'Karlskoga EK, FMCK Skövde'
#  'FMCK Stockholm' 'Anderstorp RC' 'MSK Hammaren' 'Woxnadalens MK'
#  'Hisingens MK' 'Gislaveds MK' 'Folkare MK' 'Gnesta MK' 'SMK Södermanland'
#  'Uppsala MCK'
#  'Flittig, Utenlandsk klubb, Flittig motocross & ATV, Utenlandsk klubb, Flittig, Flittig Motocross og ATV'
#  'FMCK Skövde, Tibro MK' 'Helsingborgs MCK' 'Christinehamns MK'
#  'Målilla MK Motocrossklubb' 'MK Pionjär, Kortedala MK' 'Ydre MK'
#  'Karlskoga MF' 'Frövi MF' 'Eda MK' 'Timrå EK' 'Njurunda MK'
#  'Karlskoga EK, Töreboda MK' 'FMCK Borås, Frövi MF'
#  'Karlskoga EK, FMCK Skövde, Falköpings MK' 'Limhamns MK' 'Beskaskinn MC'
#  'Hedeland MK' 'Nynäshamns MCK' 'Storfors MK' 'Grängesbergs MS'
#  'Botkyrka MK, Kullings MS' 'Mälarö MCK' 'Emsk'
#  'MSK Skinnskatteberg, Finspångs MS' 'MSK Skinnskatteberg' 'Skara MK'
#  'Hedeby MCK' 'MCK Hallandia, Helsingborgs MCK' 'Flittig'
#  'SMK Trollhättan, SMC' 'Kils MK' 'Flittig Motocross & ATV' 'Sotenäs TC'
#  'Katrineholms MCC']

# %%
import matplotlib.pyplot as plt

# Select a specific Klubb
selected_klubb = 'Falköpings MK'

# Filter data for the selected Klubb
klubb_data = ranked_dataframe[ranked_dataframe['Klubb'] == selected_klubb]

# Get all 'Namn' values for the selected Klubb
namn_values = klubb_data['Namn'].tolist()

# Extract column names for Rank values (finding columns starting with 'Rank')
rank_columns = [col for col in klubb_data.columns if col.startswith('Rank')]

# Plot Rank values for each 'Namn' in the selected Klubb
plt.figure(figsize=(10, 6))

for namn in namn_values:
    # Filter data for each 'Namn'
    rider_data = klubb_data[klubb_data['Namn'] == namn][rank_columns].values.flatten()
    
    # Plot the 'Rank' values for each 'Namn'
    plt.plot(rank_columns, rider_data, marker='o', label=namn)

plt.xlabel('Ranking Columns')
plt.ylabel('Ranking')
plt.title(f'Rankings for {selected_klubb}')
plt.legend()
plt.xticks(rank_columns, rotation=90)  # Set the x-axis ticks to Rank column names
plt.show()
